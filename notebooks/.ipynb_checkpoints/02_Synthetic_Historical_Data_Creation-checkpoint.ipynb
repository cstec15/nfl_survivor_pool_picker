# %% [markdown]
# # Synthetic Historical Data Creation
#
# In this notebook I will simulate many seasons in order to have a larger dataset to test and train our picking strategies on.

# %%
import numpy as np
import pandas as pd
import random

# %%
df = pd.read_csv("../data/df_for_simulation.csv")
df.head()
# Out:
#    Unnamed: 0  Season  Week        Date          Home Team  \
# 0           0    2024    18  2025-01-05      Detroit Lions
# 1           1    2024    18  2025-01-05  Arizona Cardinals
# 2           2    2024    18  2025-01-05    Atlanta Falcons
# 3           3    2024    18  2025-01-05     Dallas Cowboys
# 4           4    2024    18  2025-01-05     Denver Broncos
#
#                Away Team                 Winner  Home Odds Close  \
# 0      Minnesota Vikings          Detroit Lions            1.645
# 1    San Francisco 49ers      Arizona Cardinals            1.416
# 2      Carolina Panthers      Carolina Panthers            1.256
# 3  Washington Commanders  Washington Commanders            3.600
# 4     Kansas City Chiefs         Denver Broncos            1.166
#
#    Away Odds Close
# 0            2.300
# 1            2.950
# 2            4.100
# 3            1.312
# 4            5.500

# %%
def simulate_game(game_row):
    """
    Simulates the outcome of a single game based on implied win probabilities 
    derived from closing betting odds.

    Parameters:
        game_row (pd.Series): A row containing 'Home Team', 'Away Team', 
                              'Home Odds Close', and 'Away Odds Close'.

    Returns:
        str: The name of the team that is simulated to win the game.
    """
    implied_prob_home = 1/game_row['Home Odds Close']
    implied_prob_away = 1/game_row['Away Odds Close']
    implied_total = implied_prob_home + implied_prob_away
    home_prob = implied_prob_home / implied_total
    away_prob = implied_prob_away / implied_total
    teams = [game_row['Home Team'], game_row['Away Team']]
    chosen_team = np.random.choice(teams, p=[home_prob, away_prob])
    return chosen_team

# %%
simulate_game(df.iloc[0])
# Out:
# 'Minnesota Vikings'

# %%
num_sims = 500
original_df = df.copy()
all_sims = [original_df]
for i in range(num_sims):
    simmed_history = original_df.copy()
    simmed_history['Winner'] = simmed_history.apply(simulate_game, axis=1)
    simmed_history['Season'] = simmed_history['Season'].astype(str) + '_sim_' + str(i+1)
    all_sims.append(simmed_history)
    
df = pd.concat(all_sims, ignore_index=True)

# %%
df.tail()
# Out:
#          Unnamed: 0        Season  Week        Date            Home Team  \
# 2466418        4918  2006_sim_500     1  2006-09-10        Detroit Lions
# 2466419        4919  2006_sim_500     1  2006-09-10     Cleveland Browns
# 2466420        4920  2006_sim_500     1  2006-09-10    Carolina Panthers
# 2466421        4921  2006_sim_500     1  2006-09-10    Arizona Cardinals
# 2466422        4922  2006_sim_500     1  2006-09-07  Pittsburgh Steelers
#
#                    Away Team               Winner  Home Odds Close  \
# 2466418     Seattle Seahawks     Seattle Seahawks         3.500000
# 2466419   New Orleans Saints   New Orleans Saints         1.500000
# 2466420      Atlanta Falcons      Atlanta Falcons         1.434783
# 2466421  San Francisco 49ers  San Francisco 49ers         1.181818
# 2466422       Miami Dolphins  Pittsburgh Steelers         1.800000
#
#          Away Odds Close
# 2466418         1.333333
# 2466419         2.750000
# 2466420         2.900000
# 2466421         5.000000
# 2466422         2.050000

# %%
rows = []

for i, row in df.iterrows():
    rows.append({
        'Season': row['Season'],
        'Week': row['Week'],
        'Date': row['Date'],
        'Team': row['Home Team'],
        'Odds': row['Home Odds Close'],
        'Won?': row['Home Team'] == row['Winner']
    })
    rows.append({
        'Season': row['Season'],
        'Week': row['Week'],
        'Date': row['Date'],
        'Team': row['Away Team'],
        'Odds': row['Away Odds Close'],
        'Won?': row['Away Team'] == row['Winner']
    })

new_df = pd.DataFrame(rows)
new_df['Implied Prob'] = 1/ new_df['Odds']

# %%
new_df.to_csv("../data/simulated_nfl_histories")
